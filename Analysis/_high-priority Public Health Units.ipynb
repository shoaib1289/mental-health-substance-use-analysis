# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import plotly.express as px


sns.set(style="whitegrid")

df = gpd.read_file("C://Users//shoaib//Downloads//merged_phu_analysis.geojson")  # Adjust filename
# === Normalize inputs (0 to 1 scale) ===
scaler = MinMaxScaler()
df['ed_rate_norm'] = scaler.fit_transform(df[['avg_ed_rate']])
df['deprivation_norm'] = scaler.fit_transform(df[['material_resources_HUID']])
df['facilities_norm'] = scaler.fit_transform(df[['facilities_per_10k']])
df['low_facilities_norm'] = 1 - df['facilities_norm']

# Compute Composite Risk Score 
df['risk_score'] = df['ed_rate_norm'] + df['deprivation_norm'] + df['low_facilities_norm']
df['risk_score_norm'] = scaler.fit_transform(df[['risk_score']])
print(df)

# Sort and find top 5
df = df.sort_values(by='risk_score_norm', ascending=True)
top5 = df.nlargest(5, 'risk_score_norm')['HU_NAME'].tolist()

# Color for top 5
df['color'] = df['HU_NAME'].apply(lambda x: 'Top 5' if x in top5 else 'Other')

# Create interactive horizontal bar chart 
fig = px.bar(
    df,
    x='risk_score_norm',
    y='HU_NAME',
    orientation='h',
    color='color',
    color_discrete_map={'Top 5': 'crimson', 'Other': 'gray'},
    hover_data={
        'HU_NAME': True,
        'risk_score_norm': ':.2f',
        'ed_rate_norm': ':.2f',
        'deprivation_norm': ':.2f',
        'low_facilities_norm': ':.2f'
    },
    labels={
        'HU_NAME': 'Public Health Unit',
        'risk_score_norm': 'Composite Risk Score (Normalized)',
        'ed_rate_norm': 'ED Visit Risk',
        'deprivation_norm': 'Deprivation Risk',
        'low_facilities_norm': 'Facility Shortage Risk',
    },
    title='📊 Composite Risk Score by PHU — Interactive Highlighting of Top 5'
)

fig.update_layout(
    yaxis=dict(autorange='reversed'),  # Highest risk on top
    height=900,
    xaxis_title='Normalized Composite Risk Score (0–1)',
    yaxis_title='',
    showlegend=False
)

# Show plot locally 
fig.show()
# Out:
#     FID    OGF_ID  PHU_ID                                           NAME_ENG  \
# 0     1  71878062    2270                          York Region Public Health
# 1     2  71878005    5183                            Huron Perth Health Unit
# 2     3  71878059    2265                  Region of Waterloo, Public Health
# 3     4  71878029    4913                         Southwestern Public Health
# 4     5  71878057    2237                    Hamilton Public Health Services
# 5     6  71878051    2262                   Thunder Bay District Health Unit
# 6     7  71878041    2253                                 Peel Public Health
# 7     8  71878038    2242                              Lambton Public Health
# 8     9  71878035    2266             Wellington-Dufferin-Guelph Health Unit
# 9    10  71878032    2227                           Brant County Health Unit
# 10   11  71878026    2244                       Middlesex-London Health Unit
# 11   12  71878023    2261                   Sudbury and District Health Unit
# 12   13  71877993    2235  Haliburton, Kawartha, Pine Ridge District Heal...
# 13   14  71877988    2246            Niagara Region Public Health Department
# 14   15  71877985    2240                           Chatham-Kent Health Unit
# 15   16  71877982    2241  Kingston, Frontenac and Lennox and Addington H...
# 16   17  71877975    2268                   Windsor-Essex County Health Unit
# 17   18  71877972    2255                         Peterborough Public Health
# 18   19  71877970    2233                             Grey Bruce Health Unit
# 19   20  71877964    2258                        Eastern Ontario Health Unit
# 20   21  71877960    2247         North Bay Parry Sound District Health Unit
# 21   22  71877952    2251                               Ottawa Public Health
# 22   23  71877950    2243   Leeds, Grenville and Lanark District Health Unit
# 23   24  71878002    2249                           Northwestern Health Unit
# 24   25  71877945    2234                      Haldimand-Norfolk Health Unit
# 25   26  71878009    2263                            Timiskaming Health Unit
# 26   27  71877941    2257            Renfrew County and District Health Unit
# 27   28  71877938    3895                              Toronto Public Health
# 28   29  71877935    2236                    Halton Region Health Department
# 29   30  71877933    2238    Hastings and Prince Edward Counties Health Unit
# 30   31  71877929    2260                Simcoe Muskoka District Health Unit
# 31   32  71877925    2230                    Durham Region Health Department
# 32   33  71877915    2256                              Porcupine Health Unit
# 33   34  71877923    2226                          Algoma Public Health Unit
#
#                                               NAME_FR      GEO_UPD_DT  \
# 0               Service de santé de la région de York
# 1         Circonscription Sanitaire de Huron et Perth  20200515130357
# 2            Bureau de santé de la région de Waterloo
# 3                        Bureau de santé du Sud-Ouest  20200515130357
# 4              Services de santé publique de Hamilton
# 5          Bureau de santé du district de Thunder Bay
# 6                Bureau de santé de la région de Peel
# 7                                    Comté de Lambton
# 8       Bureau de santé de Wellington-Dufferin-Guelph
# 9                   Bureau de santé du comté de Brant
# 10                Bureau de santé de Middlesex-London
# 11  Service de santé publique de Sudbury et du dis...
# 12  Bureau de santé du district d'Haliburton, Kawa...
# 13            Bureau de santé de la région du Niagara
# 14                    Bureau de santé de Chatham-Kent
# 15  Bureau de santé de Kingston, Frontenac, Lennox...
# 16                   Unité sanitaire de Windsor-Essex
# 17                    Bureau de santé de Peterborough
# 18                      Bureau de santé de Grey Bruce
# 19              Bureau de santé de l'Est de l'Ontario
# 20  Bureau de santé du district de North Bay-Parry...
# 21                              Santé publique Ottawa
# 22  Bureau de santé du district de Leeds, Grenvill...
# 23                      Bureau de santé du Nord-Ouest
# 24                Bureau de santé d'Haldimand-Norfolk
# 25                   Bureau de santé de Témiskamingue
# 26  Bureau de santé du comté et du district de Ren...
# 27                         Bureau de santé de Toronto
# 28             Bureau de santé de la région de Halton
# 29       Bureau de santé de Hastings et Prince Edward
# 30                 Bureau de santé du comté de Simcoe
# 31                          Bureau de santé de Durham
# 32                          Bureau de santé Porcupine
# 33                              Santé publique Algoma
#
#           EFF_DATE    HUID  avg_ed_rate    pop2021  ...  \
# 0   20200515125615  2270.0     5.961946  1173334.0  ...
# 1   20200515125450  5183.0     9.729377   142931.0  ...
# 2   20200515125542  2265.0    17.876980   587165.0  ...
# 3   20200515125227  4913.0    20.587328   216533.0  ...
# 4   20200515125524  2237.0    29.655791   569353.0  ...
# 5   20200515125918  2262.0    39.317023   153348.0  ...
# 6   20200515125608  2253.0     9.264150  1442791.0  ...
# 7   20200515125111  2242.0    24.605633   128154.0  ...
# 8   20200515125552  2266.0    15.598997   306535.0  ...
# 9   20200515125534  2227.0    34.572159   144771.0  ...
# 10  20200515125406  2244.0    25.665996   500563.0  ...
# 11  20200515125901  2261.0    40.320907   203546.0  ...
# 12  20200515125759  2235.0    22.953318   189183.0  ...
# 13  20200515125515  2246.0    31.812756   477941.0  ...
# 14  20200515125133     NaN          NaN        NaN  ...
# 15  20200515125826     NaN          NaN        NaN  ...
# 16  20200515125050  2268.0    19.712968   423205.0  ...
# 17  20200515125821  2255.0    34.964696   147681.0  ...
# 18  20200515125748  2233.0    16.456305   175049.0  ...
# 19  20200515125842  2258.0    13.331138   210276.0  ...
# 20  20200515125802  2247.0    34.010486   129362.0  ...
# 21  20200515125839  2251.0    16.031448  1017449.0  ...
# 22  20200515125828     NaN          NaN        NaN  ...
# 23  20200515125931  2249.0    28.175390    76328.0  ...
# 24  20200515125350  2234.0    24.119763   116872.0  ...
# 25  20200515125859  2263.0    22.645758    32530.0  ...
# 26  20200515125809  2257.0    14.560134   107522.0  ...
# 27  20200515125622  3895.0    17.554270  2794356.0  ...
# 28  20200515125600  2236.0     8.404465   604868.0  ...
# 29  20200515125823  2238.0    23.278655   171450.0  ...
# 30  20200515125756  2260.0    24.895456   599843.0  ...
# 31  20200515130005  2230.0    17.712450   696992.0  ...
# 32  20200515125915  2256.0    38.842529    81554.0  ...
# 33  20200515125904  2226.0    40.795630   111694.0  ...
#
#                                               HU_NAME  facility_count  \
# 0                           York Regional Health Unit             714
# 1                             Huron Perth Health Unit             177
# 2                                Waterloo Health Unit             435
# 3                 Oxford Elgin St. Thomas Health Unit             192
# 4                        City Of Hamilton Health Unit             484
# 5                    Thunder Bay District Health Unit             216
# 6                           Peel Regional Health Unit             840
# 7                                 Lambton Health Unit             122
# 8              Wellington-Dufferin-Guelph Health Unit             242
# 9                            Brant County Health Unit             137
# 10                       Middlesex-London Health Unit             411
# 11                   Sudbury And District Health Unit             259
# 12  Haliburton, Kawartha, Pine Ridge District Heal...             197
# 13                  Niagara Regional Area Health Unit             441
# 14                                               None             116
# 15                                               None             225
# 16                   Windsor-Essex County Health Unit             368
# 17               Peterborough County-City Health Unit             132
# 18                             Grey Bruce Health Unit             181
# 19                    The Eastern Ontario Health Unit             232
# 20         North Bay Parry Sound District Health Unit             168
# 21                         City Of Ottawa Health Unit             745
# 22                                               None             220
# 23                           Northwestern Health Unit             174
# 24                      Haldimand-Norfolk Health Unit             110
# 25                            Timiskaming Health Unit              58
# 26            Renfrew County And District Health Unit             155
# 27                        City Of Toronto Health Unit            2303
# 28                        Halton Regional Health Unit             415
# 29    Hastings And Prince Edward Counties Health Unit             189
# 30                Simcoe Muskoka District Health Unit             538
# 31                        Durham Regional Health Unit             443
# 32                              Porcupine Health Unit             166
# 33                 The District Of Algoma Health Unit             169
#
#     facilities_per_10k                                           geometry  \
# 0             6.085224  POLYGON ((-79.25054 44.45334, -79.25062 44.453...
# 1            12.383598  POLYGON ((-81.74518 44.05396, -81.74273 44.053...
# 2             7.408480  POLYGON ((-80.41982 43.59024, -80.40988 43.583...
# 3             8.867009  POLYGON ((-80.73527 43.33125, -80.73508 43.321...
# 4             8.500877  POLYGON ((-79.86347 43.3402, -79.86389 43.3387...
# 5            14.085609  MULTIPOLYGON (((-88.86613 56.84778, -88.86838 ...
# 6             5.822049  POLYGON ((-79.73346 43.9153, -79.72994 43.9087...
# 7             9.519796  MULTIPOLYGON (((-81.75405 43.31557, -81.74586 ...
# 8             7.894694  POLYGON ((-80.02281 44.25004, -80.02088 44.241...
# 9             9.463221  POLYGON ((-80.22187 43.26432, -80.21823 43.254...
# 10            8.210755  POLYGON ((-81.30538 43.23857, -81.29774 43.235...
# 11           12.724396  MULTIPOLYGON (((-82.19142 48.45055, -82.0378 4...
# 12           10.413198  MULTIPOLYGON (((-78.1632 45.28194, -78.15528 4...
# 13            9.227080  MULTIPOLYGON (((-79.06764 43.25891, -79.06317 ...
# 14                 NaN  MULTIPOLYGON (((-81.87225 42.65141, -81.86919 ...
# 15                 NaN  MULTIPOLYGON (((-77.14335 45.10947, -77.13749 ...
# 16            8.695549  MULTIPOLYGON (((-82.93556 42.34245, -82.93453 ...
# 17            8.938184  POLYGON ((-78.12775 44.89378, -78.11873 44.875...
# 18           10.339962  MULTIPOLYGON (((-81.30149 45.24792, -81.29927 ...
# 19           11.033118  MULTIPOLYGON (((-74.84179 45.63617, -74.83518 ...
# 20           12.986812  MULTIPOLYGON (((-79.34376 47.00167, -79.34365 ...
# 21            7.322234  POLYGON ((-75.33532 45.52453, -75.33145 45.517...
# 22                 NaN  MULTIPOLYGON (((-76.23073 45.31399, -76.21448 ...
# 23           22.796353  MULTIPOLYGON (((-91.00001 54.50001, -91.00001 ...
# 24            9.412006  MULTIPOLYGON (((-79.75736 43.05153, -79.75413 ...
# 25           17.829696  POLYGON ((-80.84882 48.27737, -80.8128 48.2771...
# 26           14.415654  POLYGON ((-78.32167 46.25817, -78.31237 46.252...
# 27            8.241613  MULTIPOLYGON (((-79.15207 43.81444, -79.15191 ...
# 28            6.861001  POLYGON ((-79.94014 43.71287, -79.93979 43.712...
# 29           11.023622  MULTIPOLYGON (((-77.64222 45.35012, -77.64215 ...
# 30            8.969014  MULTIPOLYGON (((-78.9249 45.53368, -78.90641 4...
# 31            6.355884  POLYGON ((-79.07503 44.50008, -79.07292 44.495...
# 32           20.354612  MULTIPOLYGON (((-86.96397 55.91487, -86.96249 ...
# 33           15.130625  MULTIPOLYGON (((-84.01446 47.99208, -84.01639 ...
#
#    ed_rate_norm  deprivation_norm  facilities_norm low_facilities_norm  \
# 0      0.000000          0.334989         0.015504        9.844957e-01
# 1      0.108155          0.508735         0.386558        6.134422e-01
# 2      0.342055          0.435161         0.093461        9.065393e-01
# 3      0.419863          0.603375         0.179386        8.206136e-01
# 4      0.680199          0.816241         0.157817        8.421833e-01
# 5      0.957552          0.804432         0.486828        5.131724e-01
# 6      0.094799          0.577029         0.000000        1.000000e+00
# 7      0.535220          0.539261         0.217844        7.821562e-01
# 8      0.276659          0.278881         0.122105        8.778951e-01
# 9      0.821338          0.766072         0.214511        7.854892e-01
# 10     0.565661          0.705634         0.140725        8.592752e-01
# 11     0.986372          0.650202         0.406635        5.933649e-01
# 12     0.487786          0.558324         0.270476        7.295236e-01
# 13     0.742121          0.796021         0.200599        7.994008e-01
# 14          NaN               NaN              NaN                 NaN
# 15          NaN               NaN              NaN                 NaN
# 16     0.394762          0.980103         0.169285        8.307147e-01
# 17     0.832606          0.689001         0.183580        8.164204e-01
# 18     0.301270          0.508703         0.266162        7.338381e-01
# 19     0.211554          0.608071         0.306998        6.930025e-01
# 20     0.805213          0.851189         0.422095        5.779053e-01
# 21     0.289074          0.243344         0.088380        9.116202e-01
# 22          NaN               NaN              NaN                 NaN
# 23     0.637700          0.612198         1.000000        2.220446e-16
# 24     0.521272          0.595005         0.211494        7.885064e-01
# 25     0.478956          0.987166         0.707401        2.925986e-01
# 26     0.246835          0.581459         0.506271        4.937285e-01
# 27     0.332791          0.838120         0.142543        8.574573e-01
# 28     0.070119          0.000000         0.061207        9.387927e-01
# 29     0.497125          0.796020         0.306438        6.935619e-01
# 30     0.543540          0.514199         0.185396        8.146042e-01
# 31     0.337332          0.474380         0.031450        9.685504e-01
# 32     0.943931          0.893215         0.856151        1.438493e-01
# 33     1.000000          1.000000         0.548392        4.516078e-01
#
#     risk_score  risk_score_norm
# 0     1.319485         0.215273
# 1     1.230332         0.153477
# 2     1.683755         0.467766
# 3     1.843851         0.578736
# 4     2.338624         0.921685
# 5     2.275157         0.877694
# 6     1.671828         0.459498
# 7     1.856638         0.587598
# 8     1.433435         0.294257
# 9     2.372899         0.945443
# 10    2.130570         0.777474
# 11    2.229939         0.846351
# 12    1.775633         0.531450
# 13    2.337543         0.920936
# 14         NaN              NaN
# 15         NaN              NaN
# 16    2.205580         0.829467
# 17    2.338028         0.921272
# 18    1.543812         0.370764
# 19    1.512627         0.349148
# 20    2.234307         0.849379
# 21    1.444038         0.301606
# 22         NaN              NaN
# 23    1.249898         0.167039
# 24    1.904784         0.620970
# 25    1.758721         0.519727
# 26    1.322023         0.217032
# 27    2.028368         0.706633
# 28    1.008912         0.000000
# 29    1.986708         0.677756
# 30    1.872343         0.598485
# 31    1.780262         0.534659
# 32    1.980995         0.673796
# 33    2.451608         1.000000
#
# [34 rows x 24 columns]
